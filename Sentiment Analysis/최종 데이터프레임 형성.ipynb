# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Super_Mall_1 = '/content/drive/MyDrive/Project/LiveCommerse/OpenAI/종합몰_감성분석_정리자료_2.xlsx'
Super_Mall_Total = '/content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/종합몰_g-DMR/종합몰_total_3.xlsx'
Tour_Mall_1 = '/content/drive/MyDrive/Project/LiveCommerse/OpenAI/투어전문몰_감성분석_정리자료.xlsx'
Tour_Mall_Total = '/content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/투어전문몰_g-DMR/투어전문몰_total_3.xlsx'

# %%
df = pd.read_excel(Tour_Mall_1)
df = df[['Video_Number', 'GPT_Score_Average', 'KoBERT_Score_Average']]
df.columns = ['Video_num', 'GPT_Score_Average', 'KoBERT_Score_Average']
df.Video_num = df.Video_num.astype(str)

# %%
df.head()
# Out:
#   Video_num  GPT_Score_Average  KoBERT_Score_Average
# 0    568368               -0.2                   0.0
# 1    181889               -0.2                   0.0
# 2    840488                0.0                   0.0
# 3    700574                0.0                   0.0
# 4    473882                0.0                   0.0

# %%
total_df = pd.read_excel(Tour_Mall_Total)
total_df.dropna(subset = ['Video_num'], inplace=True)
total_df.Video_num = total_df.Video_num.astype(int)
total_df.Video_num = total_df.Video_num.astype(str)
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 416 entries, 0 to 416
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Video_num                  416 non-null    object
#  1   Channel_Name               416 non-null    object
#  2   Channel_Number             416 non-null    int64
#  3   Channel_Sub                416 non-null    int64
#  4   Channel_Total_Video        416 non-null    int64
#  5   Channel_Total_Chat         416 non-null    float64
#  6   Channel_Event_Chat         416 non-null    float64
#  7   Channel_No_Event_Chat      416 non-null    float64
#  8   Channel_Chat_User          416 non-null    float64
#  9   Channel_Chat_Positive      416 non-null    float64
#  10  Channel_Chat_Negative      416 non-null    float64
#  11  Channel_Chat_Neutral       416 non-null    float64
#  12  Channel_Sentiment_Average  411 non-null    float64
# ...

# %%
merge_df = pd.merge(total_df, df, on='Video_num')
merge_df.columns
# Out:
# Index(['Video_num', 'Channel_Name', 'Channel_Number', 'Channel_Sub',
#        'Channel_Total_Video', 'Channel_Total_Chat', 'Channel_Event_Chat',
#        'Channel_No_Event_Chat', 'Channel_Chat_User', 'Channel_Chat_Positive',
#        'Channel_Chat_Negative', 'Channel_Chat_Neutral',
#        'Channel_Sentiment_Average', 'Channel_Chat_Hello',
#        'Channel_Chat_Question', 'Channel_Average_Chat_Num',
#        'Channel_Posiotive_Rate', 'Channel_Negative_Rate',
#        'Channel_Neitral_Rate', 'Channel_Hello_Rate', 'Channel_Question_Rate',
#        'words', 'GPT_Score_Average', 'KoBERT_Score_Average'],
#       dtype='object')

# %%
merge_df = merge_df[['Video_num', 'Channel_Name', 'Channel_Number', 'Channel_Sub',
       'Channel_Total_Video', 'Channel_Total_Chat', 'Channel_Event_Chat',
       'Channel_No_Event_Chat', 'Channel_Chat_User', 'Channel_Chat_Positive',
       'Channel_Chat_Negative', 'Channel_Chat_Neutral',
       'Channel_Sentiment_Average', 'GPT_Score_Average',
       'KoBERT_Score_Average', 'Channel_Chat_Hello',
       'Channel_Chat_Question', 'Channel_Average_Chat_Num',
       'words']]

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 416 entries, 0 to 415
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Video_num                  416 non-null    object
#  1   Channel_Name               416 non-null    object
#  2   Channel_Number             416 non-null    int64
#  3   Channel_Sub                416 non-null    int64
#  4   Channel_Total_Video        416 non-null    int64
#  5   Channel_Total_Chat         416 non-null    float64
#  6   Channel_Event_Chat         416 non-null    float64
#  7   Channel_No_Event_Chat      416 non-null    float64
#  8   Channel_Chat_User          416 non-null    float64
#  9   Channel_Chat_Positive      416 non-null    float64
#  10  Channel_Chat_Negative      416 non-null    float64
#  11  Channel_Chat_Neutral       416 non-null    float64
#  12  Channel_Sentiment_Average  411 non-null    float64
# ...

# %%
merge_df.to_excel('/content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/투어전문몰_g-DMR/투어전문몰_최종_수정불가.xlsx', index=False)
