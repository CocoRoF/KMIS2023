# %%
# Install Package

# !pip install mxnet
# !pip install gluonnlp pandas tqdm
# !pip install sentencepiece
# !pip install transformers==3.0.2
# !pip install torch
# !pip install git+https://git@github.com/SKTBrain/KoBERT.git@master
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mxnet
#   Downloading mxnet-1.9.1-py3-none-manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.9/dist-packages (from mxnet) (1.22.4)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.9/dist-packages (from mxnet) (2.27.1)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.20.0->mxnet) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.20.0->mxnet) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.20.0->mxnet) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.20.0->mxnet) (2022.12.7)
# Installing collected packages: graphviz, mxnet
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.20.1
#     Uninstalling graphviz-0.20.1:
#       Successfully uninstalled graphviz-0.20.1
# Successfully installed graphviz-0.8.4 mxnet-1.9.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gluonnlp
#   Downloading gluonnlp-0.10.0.tar.gz (344 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.5/344.5 kB 10.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (4.65.0)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from gluonnlp) (1.22.4)
# Requirement already satisfied: cython in /usr/local/lib/python3.9/dist-packages (from gluonnlp) (0.29.34)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from gluonnlp) (23.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Building wheels for collected packages: gluonnlp
#   Building wheel for gluonnlp (setup.py) ... done
#   Created wheel for gluonnlp: filename=gluonnlp-0.10.0-cp39-cp39-linux_x86_64.whl size=680541 sha256=58dbd5821ad6ea076133baf6dbcd739d21e8b4a00c18783d7569c5c10930576b
#   Stored in directory: /root/.cache/pip/wheels/47/17/70/b257bc53879a458c4bfcc900e89271aa8b4f19366a54bd2455
# Successfully built gluonnlp
# Installing collected packages: gluonnlp
# Successfully installed gluonnlp-0.10.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.6 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.98
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==3.0.2
#   Downloading transformers-3.0.2-py3-none-any.whl (769 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.0/769.0 kB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.9/dist-packages (from transformers==3.0.2) (0.1.98)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from transformers==3.0.2) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from transformers==3.0.2) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers==3.0.2) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers==3.0.2) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers==3.0.2) (2022.10.31)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 59.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers==3.0.2) (3.11.0)
# Collecting tokenizers==0.8.1.rc1
#   Downloading tokenizers-0.8.1rc1.tar.gz (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.4/97.4 kB 13.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==3.0.2) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==3.0.2) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==3.0.2) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==3.0.2) (2.0.12)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==3.0.2) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==3.0.2) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==3.0.2) (1.2.0)
# Building wheels for collected packages: tokenizers, sacremoses
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for tokenizers (pyproject.toml) ... error
#   ERROR: Failed building wheel for tokenizers
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=e395f9953874887b019dacfea7f9e36d203ae5750ffa55d075fa906308bea1c8
#   Stored in directory: /root/.cache/pip/wheels/12/1c/3d/46cf06718d63a32ff798a89594b61e7f345ab6b36d909ce033
# Successfully built sacremoses
# Failed to build tokenizers
# ERROR: Could not build wheels for tokenizers, which is required to install pyproject.toml-based projects
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (2.0.0+cu118)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch) (3.11.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch) (16.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://****@github.com/SKTBrain/KoBERT.git@master
#   Cloning https://****@github.com/SKTBrain/KoBERT.git (to revision master) to /tmp/pip-req-build-g_5772px
#   Running command git clone --filter=blob:none --quiet 'https://****@github.com/SKTBrain/KoBERT.git' /tmp/pip-req-build-g_5772px
#   Resolved https://****@github.com/SKTBrain/KoBERT.git to commit 47a69af87928fc24e20f571fe10c3cc9dd9af9a3
#   Preparing metadata (setup.py) ... done
# Collecting boto3<=1.15.18
#   Downloading boto3-1.15.18-py2.py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: gluonnlp<=0.10.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from kobert==0.2.3) (0.10.0)
# Collecting mxnet<=1.7.0.post2,>=1.4.0
#   Downloading mxnet-1.7.0.post2-py2.py3-none-manylinux2014_x86_64.whl (54.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 MB 15.0 MB/s eta 0:00:00
# Collecting onnxruntime<=1.8.0,==1.8.0
#   Downloading onnxruntime-1.8.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 79.0 MB/s eta 0:00:00
# Collecting sentencepiece<=0.1.96,>=0.1.6
#   Downloading sentencepiece-0.1.96-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 73.7 MB/s eta 0:00:00
# Collecting torch<=1.10.1,>=1.7.0
#   Downloading torch-1.10.1-cp39-cp39-manylinux1_x86_64.whl (881.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.9/881.9 MB 2.0 MB/s eta 0:00:00
# Collecting transformers<=4.8.1,>=4.8.1
#   Downloading transformers-4.8.1-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 94.4 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.9/dist-packages (from onnxruntime<=1.8.0,==1.8.0->kobert==0.2.3) (23.3.3)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.9/dist-packages (from onnxruntime<=1.8.0,==1.8.0->kobert==0.2.3) (1.22.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.9/dist-packages (from onnxruntime<=1.8.0,==1.8.0->kobert==0.2.3) (3.20.3)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.7-py2.py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 9.6 MB/s eta 0:00:00
# Collecting botocore<1.19.0,>=1.18.18
#   Downloading botocore-1.18.18-py2.py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 80.6 MB/s eta 0:00:00
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: cython in /usr/local/lib/python3.9/dist-packages (from gluonnlp<=0.10.0,>=0.6.0->kobert==0.2.3) (0.29.34)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from gluonnlp<=0.10.0,>=0.6.0->kobert==0.2.3) (23.1)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.9/dist-packages (from mxnet<=1.7.0.post2,>=1.4.0->kobert==0.2.3) (2.27.1)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from mxnet<=1.7.0.post2,>=1.4.0->kobert==0.2.3) (0.8.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch<=1.10.1,>=1.7.0->kobert==0.2.3) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (3.11.0)
# Collecting huggingface-hub==0.0.12
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (4.65.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 109.0 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (2022.10.31)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (6.0)
# Collecting sacremoses
#   Using cached sacremoses-0.0.53-py3-none-any.whl
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.9/dist-packages (from botocore<1.19.0,>=1.18.18->boto3<=1.15.18->kobert==0.2.3) (2.8.2)
# Collecting urllib3<1.26,>=1.20
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.0/128.0 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.20.0->mxnet<=1.7.0.post2,>=1.4.0->kobert==0.2.3) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.20.0->mxnet<=1.7.0.post2,>=1.4.0->kobert==0.2.3) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.20.0->mxnet<=1.7.0.post2,>=1.4.0->kobert==0.2.3) (3.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers<=4.8.1,>=4.8.1->kobert==0.2.3) (1.2.0)
# Building wheels for collected packages: kobert
#   Building wheel for kobert (setup.py) ... done
#   Created wheel for kobert: filename=kobert-0.2.3-py3-none-any.whl size=15705 sha256=964416474fec5dad7494e4819da72a6679cf5ca5d47b970da82b311b063b7428
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ixrkrsr8/wheels/0b/20/d8/031374f3d29b5150c59c814bed091fca7d6d4c8218148bf286
# Successfully built kobert
# Installing collected packages: tokenizers, sentencepiece, urllib3, torch, sacremoses, onnxruntime, jmespath, botocore, s3transfer, mxnet, huggingface-hub, transformers, boto3, kobert
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.1.98
#     Uninstalling sentencepiece-0.1.98:
#       Successfully uninstalled sentencepiece-0.1.98
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.15
#     Uninstalling urllib3-1.26.15:
#       Successfully uninstalled urllib3-1.26.15
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: mxnet
#     Found existing installation: mxnet 1.9.1
#     Uninstalling mxnet-1.9.1:
#       Successfully uninstalled mxnet-1.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.15.1+cu118 requires torch==2.0.0, but you have torch 1.10.1 which is incompatible.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.10.1 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.10.1 which is incompatible.
# torchaudio 2.0.1+cu118 requires torch==2.0.0, but you have torch 1.10.1 which is incompatible.
# Successfully installed boto3-1.15.18 botocore-1.18.18 huggingface-hub-0.0.12 jmespath-0.10.0 kobert-0.2.3 mxnet-1.7.0.post2 onnxruntime-1.8.0 s3transfer-0.3.7 sacremoses-0.0.53 sentencepiece-0.1.96 tokenizers-0.10.3 torch-1.10.1 transformers-4.8.1 urllib3-1.25.11

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import os
import progressbar
import time
# Import Library

import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import gluonnlp as nlp
from tqdm import tqdm, tqdm_notebook
from kobert.utils import get_tokenizer
from kobert.pytorch_kobert import get_pytorch_kobert_model
from transformers import AdamW
from transformers.optimization import get_cosine_schedule_with_warmup

# %%
# Set GPU environment
device = torch.device("cuda:0")
# Install KoBert
bertmodel, vocab = get_pytorch_kobert_model()

# Set BERT Tokenizer

class BERTDataset(Dataset):
    def __init__(self, dataset, sent_idx, label_idx, bert_tokenizer, max_len,
                 pad, pair):
        transform = nlp.data.BERTSentenceTransform(
            bert_tokenizer, max_seq_length=max_len, pad=pad, pair=pair)

        self.sentences = [transform([i[sent_idx]]) for i in dataset]
        self.labels = [np.int32(i[label_idx]) for i in dataset]

    def __getitem__(self, i):
        return (self.sentences[i] + (self.labels[i], ))

    def __len__(self):
        return (len(self.labels))

## Setting parameters
max_len = 64
batch_size = 64
warmup_ratio = 0.1
num_epochs = 5
max_grad_norm = 1
log_interval = 200
learning_rate =  5e-5

#토큰화
tokenizer = get_tokenizer()
tok = nlp.data.BERTSPTokenizer(tokenizer, vocab, lower=False)

# KoBERT Modeling.

class BERTClassifier(nn.Module):
    def __init__(self,
                 bert,
                 hidden_size = 768,
                 num_classes=5, ##Categories. 0 = Very Negative, 1 = Negative, 2 = Neutral, 3 = Positive, 4 = Very Positive.
                 dr_rate=None,
                 params=None):
        super(BERTClassifier, self).__init__()
        self.bert = bert
        self.dr_rate = dr_rate
                 
        self.classifier = nn.Linear(hidden_size , num_classes)
        if dr_rate:
            self.dropout = nn.Dropout(p=dr_rate)
    
    def gen_attention_mask(self, token_ids, valid_length):
        attention_mask = torch.zeros_like(token_ids)
        for i, v in enumerate(valid_length):
            attention_mask[i][:v] = 1
        return attention_mask.float()

    def forward(self, token_ids, valid_length, segment_ids):
        attention_mask = self.gen_attention_mask(token_ids, valid_length)
        
        _, pooler = self.bert(input_ids = token_ids, token_type_ids = segment_ids.long(), attention_mask = attention_mask.float().to(token_ids.device))
        if self.dr_rate:
            out = self.dropout(pooler)
        return self.classifier(out)

def calc_accuracy(X,Y):
    max_vals, max_indices = torch.max(X, 1)
    train_acc = (max_indices == Y).sum().data.cpu().numpy()/max_indices.size()[0]
    return train_acc
# Out:
# /content/.cache/kobert_v1.zip[██████████████████████████████████████████████████]
# /content/.cache/kobert_news_wiki_ko_cased-1087f8699e.spiece[██████████████████████████████████████████████████]
# using cached model. /content/.cache/kobert_news_wiki_ko_cased-1087f8699e.spiece

# %%
PATH = '/content/drive/MyDrive/Project/LiveCommerse/OpenAI/KoBERT/'
model = torch.load(PATH + 'KoBERT_GPT-turn.pt')  # 전체 모델을 통째로 불러옴, 클래스 선언 필수
model.load_state_dict(torch.load(PATH + 'model_state_dict.pt'))
# Out:
# <All keys matched successfully>

# %%
main_path = '/content/drive/MyDrive/Project/LiveCommerse/'

# %%
Path_Beauty = '/content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Beauty/Video'
Path_Food = '/content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Food/Video'
Path_Life = '/content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video'
Path_Fashion = '/content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Fashion/Video'
Beauty_list = os.listdir(Path_Beauty)
Food_list = os.listdir(Path_Food)
Life_list = os.listdir(Path_Life)
Fashion_list = os.listdir(Path_Fashion)
path_list = [Path_Beauty, Path_Food, Path_Life, Path_Fashion]

# %%
# 학습된 KoBERT 불러온 뒤 예측.

def predict(predict_sentence):

    data = [predict_sentence, '0']
    dataset_another = [data]
    
    another_test = BERTDataset(dataset_another, 0, 1, tok, max_len, True, False)
    test_dataloader = torch.utils.data.DataLoader(another_test, batch_size=batch_size, num_workers=5)
    
    model.eval()

    for batch_id, (token_ids, valid_length, segment_ids, label) in enumerate(test_dataloader):
        token_ids = token_ids.long().to(device)
        segment_ids = segment_ids.long().to(device)

        valid_length= valid_length
        label = label.long().to(device)

        out = model(token_ids, valid_length, segment_ids)
        prediction = out.cpu().detach().numpy().argmax()

    return prediction

# %%
map_dict = dict({4: 2, 3: 1, 2: 0, 1: -1, 0: -2})
for path in path_list[2:3]:
  total_df = pd.DataFrame()
  video_list = os.listdir(path)
  for a, video in enumerate(video_list):
    video_num = video.split('_')[1]
    video_num = video_num.split('.')[0]
    video_path = (path + '/' + video)
    try:
      video_df = pd.read_csv(video_path)
      bar = progressbar.ProgressBar(maxval = len(video_df)).start()
      for i in range(len(video_df)):
        bar.update(i)
        video_df.loc[i, 'KoBERT_Sentiment_2'] = predict(video_df.loc[i, 'chat'])
        video_df['KoBERT_Sentiment_1'] = video_df['KoBERT_Sentiment_2'].map(lambda x: map_dict.get(x))
        video_df.to_csv(video_path)
      print(f'Done, {video_path}')
      bar.finish()
    except:
      print(f'wrong, {video_path}')
# Out:
#   0% (0 of 1124) |                       | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 1124) |                       | Elapsed Time: 0:00:00 ETA:   0:16:04/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (1124 of 1124) |####################| Elapsed Time: 0:12:35 Time:  0:12:35
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_913340.csv
#   0% (0 of 3404) |                       | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 3404) |                       | Elapsed Time: 0:00:00 ETA:   0:34:36/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (3404 of 3404) |####################| Elapsed Time: 0:50:18 Time:  0:50:18
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921262.csv
#   0% (0 of 60) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   1% (1 of 60) |                         | Elapsed Time: 0:00:00 ETA:   0:00:55/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (60 of 60) |########################| Elapsed Time: 0:01:04 Time:  0:01:04
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914631.csv
#   0% (0 of 64) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   1% (1 of 64) |                         | Elapsed Time: 0:00:00 ETA:   0:00:58/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (64 of 64) |########################| Elapsed Time: 0:01:09 Time:  0:01:09
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914634.csv
#   0% (0 of 297) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 297) |                        | Elapsed Time: 0:00:00 ETA:   0:04:28/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (297 of 297) |######################| Elapsed Time: 0:05:30 Time:  0:05:30
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911180.csv
#   0% (0 of 233) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 233) |                        | Elapsed Time: 0:00:00 ETA:   0:03:43/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (233 of 233) |######################| Elapsed Time: 0:04:28 Time:  0:04:28
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_931932.csv
#   0% (0 of 252) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 252) |                        | Elapsed Time: 0:00:00 ETA:   0:04:06/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (252 of 252) |######################| Elapsed Time: 0:04:58 Time:  0:04:58
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_933911.csv
#   0% (0 of 469) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 469) |                        | Elapsed Time: 0:00:01 ETA:   0:08:04/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (469 of 469) |######################| Elapsed Time: 0:09:41 Time:  0:09:41
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917734.csv
#   0% (0 of 419) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 419) |                        | Elapsed Time: 0:00:01 ETA:   0:07:29/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (419 of 419) |######################| Elapsed Time: 0:09:06 Time:  0:09:06
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911098.csv
#   0% (0 of 762) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 762) |                        | Elapsed Time: 0:00:01 ETA:   0:14:15/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (762 of 762) |######################| Elapsed Time: 0:17:36 Time:  0:17:36
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924109.csv
#   0% (0 of 1662) |                       | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 1662) |                       | Elapsed Time: 0:00:01 ETA:   0:33:19/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (1662 of 1662) |####################| Elapsed Time: 0:42:53 Time:  0:42:53
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_916467.csv
#   0% (0 of 60) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   1% (1 of 60) |                         | Elapsed Time: 0:00:01 ETA:   0:01:25/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (60 of 60) |########################| Elapsed Time: 0:01:42 Time:  0:01:42
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_909110.csv
#   0% (0 of 196) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 196) |                        | Elapsed Time: 0:00:01 ETA:   0:04:43/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (196 of 196) |######################| Elapsed Time: 0:05:30 Time:  0:05:30
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_916166.csv
#   0% (0 of 137) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 137) |                        | Elapsed Time: 0:00:01 ETA:   0:03:30/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (137 of 137) |######################| Elapsed Time: 0:03:51 Time:  0:03:51
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928498.csv
#   0% (0 of 197) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 197) |                        | Elapsed Time: 0:00:01 ETA:   0:04:50/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (197 of 197) |######################| Elapsed Time: 0:05:42 Time:  0:05:42
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_916565.csv
#   0% (0 of 582) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 582) |                        | Elapsed Time: 0:00:02 ETA:   0:22:02/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (582 of 582) |######################| Elapsed Time: 0:17:22 Time:  0:17:22
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_915899.csv
#   0% (0 of 331) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 331) |                        | Elapsed Time: 0:00:02 ETA:   0:11:27/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (331 of 331) |######################| Elapsed Time: 0:10:25 Time:  0:10:25
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924249.csv
#   0% (0 of 875) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 875) |                        | Elapsed Time: 0:00:01 ETA:   0:23:57/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (875 of 875) |######################| Elapsed Time: 0:28:41 Time:  0:28:41
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911090.csv
#   0% (0 of 548) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 548) |                        | Elapsed Time: 0:00:01 ETA:   0:16:19/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (548 of 548) |######################| Elapsed Time: 0:18:56 Time:  0:18:56
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_929013.csv
#   0% (0 of 674) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 674) |                        | Elapsed Time: 0:00:01 ETA:   0:20:07/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (674 of 674) |######################| Elapsed Time: 0:24:13 Time:  0:24:13
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_906382.csv
#   0% (0 of 575) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 575) |                        | Elapsed Time: 0:00:01 ETA:   0:17:49/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (575 of 575) |######################| Elapsed Time: 0:21:41 Time:  0:21:41
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_912099.csv
#   0% (0 of 1789) |                       | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 1789) |                       | Elapsed Time: 0:00:02 ETA:   1:14:16/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (1789 of 1789) |####################| Elapsed Time: 1:12:14 Time:  1:12:14
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914853.csv
#   0% (0 of 57) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   1% (1 of 57) |                         | Elapsed Time: 0:00:02 ETA:   0:01:57/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (57 of 57) |########################| Elapsed Time: 0:02:23 Time:  0:02:23
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928388.csv
#   0% (0 of 40) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   2% (1 of 40) |                         | Elapsed Time: 0:00:03 ETA:   0:02:16/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (40 of 40) |########################| Elapsed Time: 0:01:41 Time:  0:01:41
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928820.csv
#   0% (0 of 144) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 144) |                        | Elapsed Time: 0:00:03 ETA:   0:07:54/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (144 of 144) |######################| Elapsed Time: 0:06:09 Time:  0:06:09
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_916198.csv
#   0% (0 of 159) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 159) |                        | Elapsed Time: 0:00:02 ETA:   0:05:42/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (159 of 159) |######################| Elapsed Time: 0:06:47 Time:  0:06:47
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921045.csv
#   0% (0 of 380) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 380) |                        | Elapsed Time: 0:00:02 ETA:   0:13:53/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (380 of 380) |######################| Elapsed Time: 0:16:16 Time:  0:16:16
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911948.csv
#   0% (0 of 34) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   2% (1 of 34) |                         | Elapsed Time: 0:00:02 ETA:   0:01:15/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (34 of 34) |########################| Elapsed Time: 0:01:28 Time:  0:01:28
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_923388.csv
#   0% (0 of 75) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   1% (1 of 75) |                         | Elapsed Time: 0:00:02 ETA:   0:02:47/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (75 of 75) |########################| Elapsed Time: 0:03:16 Time:  0:03:16
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_929684.csv
#   0% (0 of 156) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 156) |                        | Elapsed Time: 0:00:03 ETA:   0:08:50/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (156 of 156) |######################| Elapsed Time: 0:06:47 Time:  0:06:47
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_931286.csv
#   0% (0 of 974) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 974) |                        | Elapsed Time: 0:00:02 ETA:   0:40:07/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (974 of 974) |######################| Elapsed Time: 0:43:46 Time:  0:43:46
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_918080.csv
#   0% (0 of 190) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 190) |                        | Elapsed Time: 0:00:02 ETA:   0:07:35/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (190 of 190) |######################| Elapsed Time: 0:08:44 Time:  0:08:44
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921817.csv
#   0% (0 of 147) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 147) |                        | Elapsed Time: 0:00:02 ETA:   0:06:48/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (147 of 147) |######################| Elapsed Time: 0:06:50 Time:  0:06:50
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_920197.csv
#   0% (0 of 151) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 151) |                        | Elapsed Time: 0:00:03 ETA:   0:08:19/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (151 of 151) |######################| Elapsed Time: 0:07:04 Time:  0:07:04
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_894389.csv
#   0% (0 of 384) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 384) |                        | Elapsed Time: 0:00:02 ETA:   0:15:54/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (384 of 384) |######################| Elapsed Time: 0:18:14 Time:  0:18:14
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924921.csv
#   0% (0 of 642) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 642) |                        | Elapsed Time: 0:00:02 ETA:   0:26:33/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (642 of 642) |######################| Elapsed Time: 0:31:29 Time:  0:31:29
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_916552.csv
#   0% (0 of 467) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0% (1 of 467) |                        | Elapsed Time: 0:00:03 ETA:   0:24:04/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 100% (467 of 467) |######################| Elapsed Time: 0:23:39 Time:  0:23:39
# Done, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_922711.csv
#   0% (0 of 1909) |                       | Elapsed Time: 0:00:00 ETA:  --:--:--/usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921666.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_885854.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_919339.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914717.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_931280.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_925001.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911037.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_807653.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_908588.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921796.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_906056.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_916673.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917957.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921960.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_923809.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_905115.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_919558.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_912569.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_913151.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_904662.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_919596.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_926022.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914889.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928109.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_926203.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914629.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914105.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_907503.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_929128.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921268.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924467.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_916517.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_918036.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_912031.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928113.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921374.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_915980.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_919539.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921413.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_918449.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928348.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914556.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_916483.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924924.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924469.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_906392.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_918757.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_925608.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_904266.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_904925.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928151.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_916995.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_934438.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917805.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914110.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_926152.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_835482.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_923804.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924401.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_904956.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_906531.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928595.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_929035.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_920225.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_930219.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917570.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_913888.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924843.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917287.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_920541.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921199.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_900955.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_933401.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924945.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_925213.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_925866.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911817.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_929340.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_913599.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_929941.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_907568.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_920028.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_906675.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_913473.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_908384.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_908551.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_919813.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_905454.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911252.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_913200.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914367.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921333.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_902090.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914918.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911956.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_912708.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_913130.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917372.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_922658.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_913393.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924376.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_913177.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_922705.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911503.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921510.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_922867.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_922496.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_932217.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_908821.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924908.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_913388.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_922702.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_908420.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_933691.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924384.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928508.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_929954.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_931687.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_907560.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928626.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_907571.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924816.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924933.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_912705.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911332.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_915654.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_905666.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_923808.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921352.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917203.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911229.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924043.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928621.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_913764.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917634.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_926233.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924486.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914414.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_930414.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_904879.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924294.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_926219.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_915735.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_921024.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_922703.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928637.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_929931.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924283.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924948.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_909173.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_926146.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_908880.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_907818.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914864.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928253.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911914.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917222.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_922523.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_914624.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_930242.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917374.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_924594.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911356.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_926297.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_911982.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_925909.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_931344.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917268.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_928140.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917357.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_903624.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917236.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_926641.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_902122.csv
# wrong, /content/drive/MyDrive/Project/LiveCommerse/FUCKUGOOGLE/Life/Video/Video_917261.csv
