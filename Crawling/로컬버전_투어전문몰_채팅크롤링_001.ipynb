# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from pathos.multiprocessing import ProcessingPool
from pathos.multiprocessing import ProcessPool
import os
import progressbar
import pickle

# %%
df = pd.read_csv('/Users/jang/Library/CloudStorage/GoogleDrive-gkfua00@gmail.com/내 드라이브/LiveCommerse/Total_DataFrame.csv')
df2 = df.sort_values(by='Num_Sub', ascending=False)
df3 = df2[df2['Tour/Experience'] == 1]
df4 = df3[(df3['Food']==0) & (df3['Beauty']==0) & (df3['Life']==0) & (df3['Fashion']==0) & (df3['Kids']==0) & (df3['Tech']==0) & (df3['Hobby/Leisure']==0) & (df3['Culture']==0)]
df5 = df3[(df3['Food']==1) | (df3['Beauty']==1) | (df3['Life']==1) | (df3['Fashion']==1) | (df3['Kids']==1) | (df3['Tech']==1) | (df3['Hobby/Leisure']==1) | (df3['Culture']==1)]
# Out:
# /var/folders/dt/cjg6bnms6qqf7rxtdqjr4rk00000gn/T/ipykernel_84259/1630716991.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/jang/Library/CloudStorage/GoogleDrive-gkfua00@gmail.com/내 드라이브/LiveCommerse/Total_DataFrame.csv')

# %%
df5.Num_Video = df5['Num_Video'].astype(int)
# Out:
# /var/folders/dt/cjg6bnms6qqf7rxtdqjr4rk00000gn/T/ipykernel_84259/803618846.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.Num_Video = df5['Num_Video'].astype(int)

# %%
df5.describe()
# Out:
#        Channel_number        Num_Sub   Num_Video    Total_View      Best_View  \
# count      116.000000     116.000000  116.000000  1.160000e+02     116.000000
# mean     65675.017241   14644.534483   70.422414  2.271034e+05   41777.620690
# std      23013.380084   49259.027292  135.537715  6.355159e+05   79737.331325
# min        157.000000      31.000000    0.000000  0.000000e+00       0.000000
# 25%      61175.500000     419.500000    9.750000  1.416775e+04    2077.750000
# 50%      68167.500000    1057.500000   21.500000  2.526950e+04    6756.500000
# 75%      80379.500000    4340.500000   71.250000  9.718125e+04   23250.000000
# max     102929.000000  390000.000000  966.000000  4.432585e+06  400000.000000
#
#          Worst_View      Beauty        Food    Fashion        Life  \
# count    116.000000  116.000000  116.000000  116.00000  116.000000
# mean    2657.620690    0.534483    0.689655    0.37931    0.637931
# std     8002.305098    0.500974    0.464642    0.48732    0.482684
# min        0.000000    0.000000    0.000000    0.00000    0.000000
# 25%      327.500000    0.000000    0.000000    0.00000    0.000000
# 50%      567.000000    1.000000    1.000000    0.00000    1.000000
# 75%     1056.500000    1.000000    1.000000    1.00000    1.000000
# max    57000.000000    1.000000    1.000000    1.00000    1.000000
#
#        Tour/Experience        Kids        Tech  Hobby/Leisure     Culture
# count            116.0  116.000000  116.000000     116.000000  116.000000
# mean               1.0    0.284483    0.189655       0.301724    0.163793
# std                0.0    0.453125    0.393729       0.460998    0.371693
# min                1.0    0.000000    0.000000       0.000000    0.000000
# 25%                1.0    0.000000    0.000000       0.000000    0.000000
# 50%                1.0    0.000000    0.000000       0.000000    0.000000
# 75%                1.0    1.000000    0.000000       1.000000    0.000000
# max                1.0    1.000000    1.000000       1.000000    1.000000

# %%
tour_df = df4[['Channel_Name', 'Channel_number', 'Num_Video']]
tour_df['Num_Video'] = tour_df['Num_Video'].astype(int)
# Out:
# /var/folders/dt/cjg6bnms6qqf7rxtdqjr4rk00000gn/T/ipykernel_6213/3005887218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tour_df['Num_Video'] = tour_df['Num_Video'].astype(int)

# %%
df4
# Out:
#       Channel_Name  Channel_number   Num_Sub Num_Video  Total_View  Best_View  \
# 60405     네이버 여행상품           66400  280000.0        47   1240901.0   290000.0
# 61523         에버랜드           67619   44000.0        14    682000.0   120000.0
# 63871        아쿠아필드           70207   25000.0        11    305756.0    44000.0
# 69623         경주월드           76553   21000.0         8    282000.0    65000.0
# 59702        올마이투어           65650   17000.0        26    817000.0   100000.0
# ...            ...             ...       ...       ...         ...        ...
# 77205         어디갈래           84729      51.0         1      7760.0     7760.0
# 73497         이잼투어           80758      46.0         1       588.0      588.0
# 77556         제주페이           85124      41.0         1      1139.0     1139.0
# 82846         미르숲샵           90708      29.0         2      1219.0      747.0
# 85623       인천관광공사           93629      18.0         1     21000.0    21000.0
#
#        Worst_View  Beauty  Food  Fashion  Life  Tour/Experience  Kids  Tech  \
# 60405      4295.0       0     0        0     0                1     0     0
# 61523     22000.0       0     0        0     0                1     0     0
# 63871      6756.0       0     0        0     0                1     0     0
# 69623     18000.0       0     0        0     0                1     0     0
# 59702     19000.0       0     0        0     0                1     0     0
# ...           ...     ...   ...      ...   ...              ...   ...   ...
# 77205      7760.0       0     0        0     0                1     0     0
# 73497       588.0       0     0        0     0                1     0     0
# 77556      1139.0       0     0        0     0                1     0     0
# 82846       472.0       0     0        0     0                1     0     0
# 85623     21000.0       0     0        0     0                1     0     0
#
#        Hobby/Leisure  Culture
# 60405              0        0
# 61523              0        0
# 63871              0        0
# 69623              0        0
# 59702              0        0
# ...              ...      ...
# 77205              0        0
# 73497              0        0
# 77556              0        0
# 82846              0        0
# 85623              0        0
#
# [107 rows x 16 columns]

# %%
chrome_driver_path = '/Users/jang/Library/CloudStorage/GoogleDrive-gkfua00@gmail.com/내 드라이브/chromedriver_mac64/chromedriver'

class MyCrawler:
    def __init__(self, numprocess, path_save):
        self.n_process = numprocess
        self.pool = ProcessPool(nodes=self.n_process)
        self.path_save = path_save
        
    def multi_processing(self, sites):
        def chat_crawler(url):
            # 사용하는 Library Import
            from selenium import webdriver
            from bs4 import BeautifulSoup
            from selenium.webdriver.common.by import By
            from selenium.webdriver.chrome.options import Options
            from selenium.webdriver.chrome.service import Service
            from webdriver_manager.chrome import ChromeDriverManager
            import time
            import os
            chrome_driver_path = '/Users/jang/Library/CloudStorage/GoogleDrive-gkfua00@gmail.com/내 드라이브/chromedriver_mac64/chromedriver'
            chrome_options = Options()
            chrome_options.add_argument("--headless")
            # driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
            driver = webdriver.Chrome(chrome_driver_path, options=chrome_options)

            # 원하는 사이트 로드
            driver.get(url)
            save_number = str(url)
            save_number = save_number[44:50]
            
            # 1분 대기 ... 여러 사이트 열어서 시간이 좀 걸림.
            time.sleep(30)

            # 자동으로 2배속 설정.
            buttun = driver.find_element(By.XPATH, '//*[@id="product-root"]/div/div/div/div/div/div[3]/div[2]/div[2]/div/div[3]/div[2]/button[1]')
            buttun.click()
            time.sleep(1)
            buttun.click()
            
            # 반복 횟수 설정.
            repeat_n = 24
            empty = []
            df = pd.DataFrame({'name' : empty, 'chat' : empty})
            
            # 채팅 및 아이디 크롤링.
            for re_n in range(repeat_n):
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                temp_list = soup.select('div.CommentList_animation_area_Ca5J9')
            
                chat_list_temp = []
                for i in temp_list:
                    for j in i:
                        for k in j:
                            chat = k.select('span')
                            chat = str(chat)
                            chat_list_temp.append(chat)

                name_list_temp = []
                for i in temp_list:
                    for j in i:
                        name = j.select('strong')
                        name = str(name)
                        if 'nickname' in name:
                            name_list_temp.append(name)

                chat_list = []
                for i in chat_list_temp:
                    try:
                        i = (i.split('<')[1])
                        i = (i.split('>')[1])
                        chat_list.append(i)
                    except:
                        continue
                    
                name_list = []
                for i in name_list_temp:
                    try:
                        i = (i.split('<')[1])
                        i = (i.split('>')[1])
                        name_list.append(i)
                    except:
                        continue
                df_temp = pd.DataFrame({ 'name' : name_list, 'chat' : chat_list})
                df = pd.concat([df, df_temp], ignore_index=True)
                df.drop_duplicates(inplace=True)
                df.reset_index(drop=True, inplace=True)
                df.to_csv(self.path_save + '/Video_{}.csv' .format(save_number), index=False)
                time.sleep(200)

            # df 형성 및 저장.
            df.drop_duplicates(inplace=True)
            df.reset_index(drop=True, inplace=True)
            df.to_csv(self.path_save + '/Video_{}.csv' .format(save_number), index=False)
            
            driver.quit()
        
        self.pool.map(chat_crawler, sites)

# %%
path = '/Users/jang/Library/CloudStorage/GoogleDrive-gkfua00@gmail.com/내 드라이브/LiveCommerse/FUCKUGOOGLE/Tour_only_df/'
Complete_list = []
fail_list = []

for i in range(len(tour_df)):
    temp = tour_df.iloc[i]
    temp_id = temp[0]
    temp_number = temp[1]
    temp_video = temp[2]
    
    if temp_video > 20:
        print(temp_id, temp_number)
    
    else:
        dir_path = path + f'{temp_id}_{temp_number}'
        try:
            os.mkdir(dir_path)
        except:
            continue
        chrome_driver_path = '/Users/jang/Library/CloudStorage/GoogleDrive-gkfua00@gmail.com/내 드라이브/chromedriver_mac64/chromedriver'
        chrome_options = Options()
        chrome_options.add_argument("--headless")
        driver = webdriver.Chrome(chrome_driver_path, options=chrome_options)
        url = f'https://shoppinglive.naver.com/channels/{temp_number}'
        driver.get(url)
        time.sleep(1)
    
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        url_list = soup.select('a.VideoBoxLinkWrapper_wrap_GLkZS')
        
        temp_list = []
        for j in url_list:
            j = str(j)
            j = j.split('href="')[1]
            j = j.split('"><div')[0]
            temp_list.append(j)
        
        n = 5
        slice_list = [temp_list[i*n : n*(i+1)] for i in range(0, (len(temp_list) + n -1)//n)]
        k = len(slice_list)
        
        print(f'Channel {temp_id}_{temp_number} Crawling start. K = {k}')
        
        for p, l in enumerate(slice_list):
            print('k = {} start' .format(p+1))
            try:
                print('Processing ...')
                print(l)
                Crawler = MyCrawler(len(l), dir_path)
                Crawler.multi_processing(l)
            except:
                print(f'Fail. Channel = {temp_id}, Number = {temp_number}')
                print(l)
                
        Complete_list.append(temp_number)
        with open('/Users/jang/Library/CloudStorage/GoogleDrive-gkfua00@gmail.com/내 드라이브/LiveCommerse/FUCKUGOOGLE/Tour_only_df/Complete_list.pkl', 'wb') as f:
            pickle.dump(Complete_list, f)
        print(f'Channel {temp_id}_{temp_number} Crawling End.')
# Out:
# 네이버 여행상품 66400
# 올마이투어 65650
# 여행온여수 78265
# /var/folders/dt/cjg6bnms6qqf7rxtdqjr4rk00000gn/T/ipykernel_3165/669681658.py:23: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_driver_path, options=chrome_options)
# Channel 브이패스_38573 Crawling start. K = 1
# k = 1 start
# Processing ...
# ['https://view.shoppinglive.naver.com/replays/901669?fm=shoppinglive&amp;sn=home', 'https://view.shoppinglive.naver.com/replays/866961?fm=shoppinglive&amp;sn=home']
# /var/folders/dt/cjg6bnms6qqf7rxtdqjr4rk00000gn/T/ipykernel_3165/2034540665.py:24: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_driver_path, options=chrome_options)
# /var/folders/dt/cjg6bnms6qqf7rxtdqjr4rk00000gn/T/ipykernel_3165/2034540665.py:24: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_driver_path, options=chrome_options)
# The process has forked and you cannot use this CoreFoundation functionality safely. You MUST exec().
# Break on __THE_PROCESS_HAS_FORKED_AND_YOU_CANNOT_USE_THIS_COREFOUNDATION_FUNCTIONALITY___YOU_MUST_EXEC__() to debug.
# The process has forked and you cannot use this CoreFoundation functionality safely. You MUST exec().
# Break on __THE_PROCESS_HAS_FORKED_AND_YOU_CANNOT_USE_THIS_COREFOUNDATION_FUNCTIONALITY___YOU_MUST_EXEC__() to debug.
# Fail. Channel = 브이패스, Number = 38573
# ['https://view.shoppinglive.naver.com/replays/901669?fm=shoppinglive&amp;sn=home', 'https://view.shoppinglive.naver.com/replays/866961?fm=shoppinglive&amp;sn=home']
# Channel 브이패스_38573 Crawling End.
# Channel LSCOMPANY_54844 Crawling start. K = 4
# k = 1 start
# Processing ...
# ['https://view.shoppinglive.naver.com/replays/894149?fm=shoppinglive&amp;sn=home', 'https://view.shoppinglive.naver.com/replays/852687?fm=shoppinglive&amp;sn=home', 'https://view.shoppinglive.naver.com/replays/831597?fm=shoppinglive&amp;sn=home', 'https://view.shoppinglive.naver.com/replays/815036?fm=shoppinglive&amp;sn=home', 'https://view.shoppinglive.naver.com/replays/817764?fm=shoppinglive&amp;sn=home']
# /var/folders/dt/cjg6bnms6qqf7rxtdqjr4rk00000gn/T/ipykernel_3165/2034540665.py:24: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_driver_path, options=chrome_options)
# /var/folders/dt/cjg6bnms6qqf7rxtdqjr4rk00000gn/T/ipykernel_3165/2034540665.py:24: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_driver_path, options=chrome_options)
# /var/folders/dt/cjg6bnms6qqf7rxtdqjr4rk00000gn/T/ipykernel_3165/2034540665.py:24: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_driver_path, options=chrome_options)
# /var/folders/dt/cjg6bnms6qqf7rxtdqjr4rk00000gn/T/ipykernel_3165/2034540665.py:24: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_driver_path, options=chrome_options)
# /var/folders/dt/cjg6bnms6qqf7rxtdqjr4rk00000gn/T/ipykernel_3165/2034540665.py:24: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_driver_path, options=chrome_options)
